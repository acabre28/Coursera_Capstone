# %% [markdown]
# ### Introduction

# %% [markdown]
# A recent university graduate has decided to move from Miami, Florida to Toronto, Canada and open a Cuban restaurant.  In Miami, 54% of the city's population is Cuban, which helps explain the popularity of the many Cuban restaurants in the area.  Unfortunately for a new business owner, opening a restaurant where the menu items are already popular may have its challenges and could cause the business to be unsuccessful very early on.  The graduate decides to take a leap of faith and move to Canada in hope of success, where the third largest Cuban immigrant community resides.  The following factors will have to be evaluated in order to do well: location and demographic of location, price of menu items, and surrounding competition.

# %% [markdown]
# ### Business Problem

# %% [markdown]
# In which neighborhood of Toronto should the graduate open their Cuban restaurant?

# %% [markdown]
# ### Data

# %% [markdown]
# In order to find a solution to this business problem I will be using Foursquare API to determine the following: which neighborhoods have a high percentage of Cubans residing, where the most popular Cuban restaurants are located, and to evaluate the price of popular menu items at those restaurants. With this data, I will then use K-Means Clustering to find the best neighborhood for the restaurant.

# %%
# Import Libraries
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import json
from geopy.geocoders import Nominatim
import requests
from pandas.io.json import json_normalize
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import folium

# %%
# Get Canada data
url = requests.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M").text
from bs4 import BeautifulSoup
soup = BeautifulSoup(url, 'lxml')
# Extract the table 
table = soup.find('table', {'class':'wikitable sortable'})
table_1 = table.find_all('tr')
data = []
for row in table_1:
    td=[]
    for t in row.find_all('td'):
        td.append(t.text.strip())
    data.append(td)
# Create DataFrame
df = pd.DataFrame(data, columns = ['PostalCode', 'Borough', 'Neighborhood'])
df = df[~df['Borough'].isnull()]
df.drop(df[df.Borough == 'Not assigned'].index, inplace=True)
df.reset_index(drop=True, inplace=True)
df = df.groupby(['PostalCode','Borough'])['Neighborhood'].apply(lambda x: ','.join(x)).reset_index()
df['Neighborhood'].replace('Not assigned',df['Borough'],inplace=True)
# Read geographical csv
geo_df = pd.read_csv("https://cocl.us/Geospatial_data")
geo_df.rename(columns = {'Postal Code':'PostalCode'}, inplace = True)
# Merge df and geo_df
merge = pd.merge(df, geo_df, on = 'PostalCode')
# Get Toronto data
toronto = merge[merge['Borough'].str.contains('Toronto',regex=False)]
toronto
# Out:
#    PostalCode           Borough  \
# 37        M4E      East Toronto
# 41        M4K      East Toronto
# 42        M4L      East Toronto
# 43        M4M      East Toronto
# 44        M4N   Central Toronto
# 45        M4P   Central Toronto
# 46        M4R   Central Toronto
# 47        M4S   Central Toronto
# 48        M4T   Central Toronto
# 49        M4V   Central Toronto
# 50        M4W  Downtown Toronto
# 51        M4X  Downtown Toronto
# 52        M4Y  Downtown Toronto
# 53        M5A  Downtown Toronto
# 54        M5B  Downtown Toronto
# 55        M5C  Downtown Toronto
# 56        M5E  Downtown Toronto
# 57        M5G  Downtown Toronto
# 58        M5H  Downtown Toronto
# 59        M5J  Downtown Toronto
# 60        M5K  Downtown Toronto
# 61        M5L  Downtown Toronto
# 63        M5N   Central Toronto
# 64        M5P   Central Toronto
# 65        M5R   Central Toronto
# 66        M5S  Downtown Toronto
# 67        M5T  Downtown Toronto
# 68        M5V  Downtown Toronto
# 69        M5W  Downtown Toronto
# 70        M5X  Downtown Toronto
# 75        M6G  Downtown Toronto
# 76        M6H      West Toronto
# 77        M6J      West Toronto
# 78        M6K      West Toronto
# 82        M6P      West Toronto
# 83        M6R      West Toronto
# 84        M6S      West Toronto
# 85        M7A  Downtown Toronto
# 87        M7Y      East Toronto
#
#                                          Neighborhood   Latitude  Longitude
# 37                                        The Beaches  43.676357 -79.293031
# 41                       The Danforth West, Riverdale  43.679557 -79.352188
# 42                     India Bazaar, The Beaches West  43.668999 -79.315572
# 43                                    Studio District  43.659526 -79.340923
# 44                                      Lawrence Park  43.728020 -79.388790
# 45                                   Davisville North  43.712751 -79.390197
# 46                 North Toronto West,  Lawrence Park  43.715383 -79.405678
# 47                                         Davisville  43.704324 -79.388790
# 48                        Moore Park, Summerhill East  43.689574 -79.383160
# 49  Summerhill West, Rathnelly, South Hill, Forest...  43.686412 -79.400049
# 50                                           Rosedale  43.679563 -79.377529
# 51                        St. James Town, Cabbagetown  43.667967 -79.367675
# 52                               Church and Wellesley  43.665860 -79.383160
# 53                          Regent Park, Harbourfront  43.654260 -79.360636
# 54                           Garden District, Ryerson  43.657162 -79.378937
# 55                                     St. James Town  43.651494 -79.375418
# 56                                        Berczy Park  43.644771 -79.373306
# 57                                 Central Bay Street  43.657952 -79.387383
# 58                           Richmond, Adelaide, King  43.650571 -79.384568
# 59  Harbourfront East, Union Station, Toronto Islands  43.640816 -79.381752
# 60           Toronto Dominion Centre, Design Exchange  43.647177 -79.381576
# 61                     Commerce Court, Victoria Hotel  43.648198 -79.379817
# 63                                           Roselawn  43.711695 -79.416936
# 64    Forest Hill North & West, Forest Hill Road Park  43.696948 -79.411307
# 65                The Annex, North Midtown, Yorkville  43.672710 -79.405678
# 66                     University of Toronto, Harbord  43.662696 -79.400049
# 67          Kensington Market, Chinatown, Grange Park  43.653206 -79.400049
# 68  CN Tower, King and Spadina, Railway Lands, Har...  43.628947 -79.394420
# 69                                     Stn A PO Boxes  43.646435 -79.374846
# 70             First Canadian Place, Underground city  43.648429 -79.382280
# 75                                           Christie  43.669542 -79.422564
# 76                       Dufferin, Dovercourt Village  43.669005 -79.442259
# 77                           Little Portugal, Trinity  43.647927 -79.419750
# 78       Brockton, Parkdale Village, Exhibition Place  43.636847 -79.428191
# 82                      High Park, The Junction South  43.661608 -79.464763
# 83                             Parkdale, Roncesvalles  43.648960 -79.456325
# 84                                 Runnymede, Swansea  43.651571 -79.484450
# 85        Queen's Park, Ontario Provincial Government  43.662301 -79.389494
# 87  Business reply mail Processing Centre, South C...  43.662744 -79.321558

# %% [markdown]
# Now that we have our data on the neighborhoods in Toronto, we need to figure out what the demographic is for each.

# %%
# Create DataFrame for Deomgraphics data
import pandas as pd
info = [('M4E','#5',215),('M4K','#6',125),('M4L','#5',140),('M4M','#6',305),
        ('M4P','#6',70),('M4R','#6',115),('M4S','#5',285),('M4T','#5',270),
        ('M4V','#4',220),('M4W','#5',270),('M4X','#5',260),('M4Y','#5',700),
        ('M5A','#5',1405),('M5B','#5',700),('M5C','#5',700),('M5E','#5',700),
        ('M5G','#7',455),('M5H','#7',455),('M5J','#5',1405),('M5K','#5',455),
        ('M5L','#5',455),('M5N','#7',115),('M5P','#7',215),('M5R','#5',410),
        ('M5S','#6',125),('M5T','#7',325),('M5V','#4',1005),('M5W','#7',115),
        ('M5X','#5',455),('M6G','#4',235),('M6H','#4',1515),('M6J','#4',185),
        ('M6K','#6',510),('M6P','#5',490),('M6R','#6',285),('M6S','#4',475),
        ('M7A','#5',400),('M7Y','#7',115)]
demo = pd.DataFrame(info, columns = ["PostalCode", "Latin American Minority Ranking", "Number of Latin Americans (2016)"])
demo
# Out:
#    PostalCode Latin American Minority Ranking  \
# 0         M4E                              #5
# 1         M4K                              #6
# 2         M4L                              #5
# 3         M4M                              #6
# 4         M4P                              #6
# 5         M4R                              #6
# 6         M4S                              #5
# 7         M4T                              #5
# 8         M4V                              #4
# 9         M4W                              #5
# 10        M4X                              #5
# 11        M4Y                              #5
# 12        M5A                              #5
# 13        M5B                              #5
# 14        M5C                              #5
# 15        M5E                              #5
# 16        M5G                              #7
# 17        M5H                              #7
# 18        M5J                              #5
# 19        M5K                              #5
# 20        M5L                              #5
# 21        M5N                              #7
# 22        M5P                              #7
# 23        M5R                              #5
# 24        M5S                              #6
# 25        M5T                              #7
# 26        M5V                              #4
# 27        M5W                              #7
# 28        M5X                              #5
# 29        M6G                              #4
# 30        M6H                              #4
# 31        M6J                              #4
# 32        M6K                              #6
# 33        M6P                              #5
# 34        M6R                              #6
# 35        M6S                              #4
# 36        M7A                              #5
# 37        M7Y                              #7
#
#     Number of Latin Americans (2016)
# 0                                215
# 1                                125
# 2                                140
# 3                                305
# 4                                 70
# 5                                115
# 6                                285
# 7                                270
# 8                                220
# 9                                270
# 10                               260
# 11                               700
# 12                              1405
# 13                               700
# 14                               700
# 15                               700
# 16                               455
# 17                               455
# 18                              1405
# 19                               455
# 20                               455
# 21                               115
# 22                               215
# 23                               410
# 24                               125
# 25                               325
# 26                              1005
# 27                               115
# 28                               455
# 29                               235
# 30                              1515
# 31                               185
# 32                               510
# 33                               490
# 34                               285
# 35                               475
# 36                               400
# 37                               115

# %%
# Merge Toronto data and Demographics data
combo = pd.merge(toronto, demo, on = 'PostalCode')
combo
# Out:
#    PostalCode           Borough  \
# 0         M4E      East Toronto
# 1         M4K      East Toronto
# 2         M4L      East Toronto
# 3         M4M      East Toronto
# 4         M4P   Central Toronto
# 5         M4R   Central Toronto
# 6         M4S   Central Toronto
# 7         M4T   Central Toronto
# 8         M4V   Central Toronto
# 9         M4W  Downtown Toronto
# 10        M4X  Downtown Toronto
# 11        M4Y  Downtown Toronto
# 12        M5A  Downtown Toronto
# 13        M5B  Downtown Toronto
# 14        M5C  Downtown Toronto
# 15        M5E  Downtown Toronto
# 16        M5G  Downtown Toronto
# 17        M5H  Downtown Toronto
# 18        M5J  Downtown Toronto
# 19        M5K  Downtown Toronto
# 20        M5L  Downtown Toronto
# 21        M5N   Central Toronto
# 22        M5P   Central Toronto
# 23        M5R   Central Toronto
# 24        M5S  Downtown Toronto
# 25        M5T  Downtown Toronto
# 26        M5V  Downtown Toronto
# 27        M5W  Downtown Toronto
# 28        M5X  Downtown Toronto
# 29        M6G  Downtown Toronto
# 30        M6H      West Toronto
# 31        M6J      West Toronto
# 32        M6K      West Toronto
# 33        M6P      West Toronto
# 34        M6R      West Toronto
# 35        M6S      West Toronto
# 36        M7A  Downtown Toronto
# 37        M7Y      East Toronto
#
#                                          Neighborhood   Latitude  Longitude  \
# 0                                         The Beaches  43.676357 -79.293031
# 1                        The Danforth West, Riverdale  43.679557 -79.352188
# 2                      India Bazaar, The Beaches West  43.668999 -79.315572
# 3                                     Studio District  43.659526 -79.340923
# 4                                    Davisville North  43.712751 -79.390197
# 5                  North Toronto West,  Lawrence Park  43.715383 -79.405678
# 6                                          Davisville  43.704324 -79.388790
# 7                         Moore Park, Summerhill East  43.689574 -79.383160
# 8   Summerhill West, Rathnelly, South Hill, Forest...  43.686412 -79.400049
# 9                                            Rosedale  43.679563 -79.377529
# 10                        St. James Town, Cabbagetown  43.667967 -79.367675
# 11                               Church and Wellesley  43.665860 -79.383160
# 12                          Regent Park, Harbourfront  43.654260 -79.360636
# 13                           Garden District, Ryerson  43.657162 -79.378937
# 14                                     St. James Town  43.651494 -79.375418
# 15                                        Berczy Park  43.644771 -79.373306
# 16                                 Central Bay Street  43.657952 -79.387383
# 17                           Richmond, Adelaide, King  43.650571 -79.384568
# 18  Harbourfront East, Union Station, Toronto Islands  43.640816 -79.381752
# 19           Toronto Dominion Centre, Design Exchange  43.647177 -79.381576
# 20                     Commerce Court, Victoria Hotel  43.648198 -79.379817
# 21                                           Roselawn  43.711695 -79.416936
# 22    Forest Hill North & West, Forest Hill Road Park  43.696948 -79.411307
# 23                The Annex, North Midtown, Yorkville  43.672710 -79.405678
# 24                     University of Toronto, Harbord  43.662696 -79.400049
# 25          Kensington Market, Chinatown, Grange Park  43.653206 -79.400049
# 26  CN Tower, King and Spadina, Railway Lands, Har...  43.628947 -79.394420
# 27                                     Stn A PO Boxes  43.646435 -79.374846
# 28             First Canadian Place, Underground city  43.648429 -79.382280
# 29                                           Christie  43.669542 -79.422564
# 30                       Dufferin, Dovercourt Village  43.669005 -79.442259
# 31                           Little Portugal, Trinity  43.647927 -79.419750
# 32       Brockton, Parkdale Village, Exhibition Place  43.636847 -79.428191
# 33                      High Park, The Junction South  43.661608 -79.464763
# 34                             Parkdale, Roncesvalles  43.648960 -79.456325
# 35                                 Runnymede, Swansea  43.651571 -79.484450
# 36        Queen's Park, Ontario Provincial Government  43.662301 -79.389494
# 37  Business reply mail Processing Centre, South C...  43.662744 -79.321558
#
#    Latin American Minority Ranking  Number of Latin Americans (2016)
# 0                               #5                               215
# 1                               #6                               125
# 2                               #5                               140
# 3                               #6                               305
# 4                               #6                                70
# 5                               #6                               115
# 6                               #5                               285
# 7                               #5                               270
# 8                               #4                               220
# 9                               #5                               270
# 10                              #5                               260
# 11                              #5                               700
# 12                              #5                              1405
# 13                              #5                               700
# 14                              #5                               700
# 15                              #5                               700
# 16                              #7                               455
# 17                              #7                               455
# 18                              #5                              1405
# 19                              #5                               455
# 20                              #5                               455
# 21                              #7                               115
# 22                              #7                               215
# 23                              #5                               410
# 24                              #6                               125
# 25                              #7                               325
# 26                              #4                              1005
# 27                              #7                               115
# 28                              #5                               455
# 29                              #4                               235
# 30                              #4                              1515
# 31                              #4                               185
# 32                              #6                               510
# 33                              #5                               490
# 34                              #6                               285
# 35                              #4                               475
# 36                              #5                               400
# 37                              #7                               115

# %% [markdown]
# Now that we have the combined dataframe, we can observe the presence of Latin Americans in each neighborhood of Toronto, Canada.  Based on this data, specifically the rankings and the number of Latin Americans, we will use Foursquare API to explore the following neighborhoods further: Summerhill West, Regent Park, Harbourfront East, CN Tower, Christie, Dufferin, Little Portugal, and Runnymede.

# %% [markdown]
# ### Using Foursquare API to find the top 25 Cuban restaurants in Toronto

# %%
#Import Libraries
from pandas.io.json import json_normalize
import folium
from geopy.geocoders import Nominatim
import requests

# %%
# Foursquare Credentials
CLIENT_ID = "NNZ3OPEXWX5TTA0BHMRUDHIJ1PNX33FNFDRISIXG1L0U4LDK"
CLIENT_SECRET = "ZOCUQVSR4CRYINTSOFE1THKJG0LMRJN2CTP2DLD0R53HM2OZ"
VERSION = "20180604"
LIMIT = 50

# %%
# Find Latitude and Longitude
address = 'Toronto, Canada'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 43.6534817 -79.3839347

# %%
search_query = 'Carribean Restaurant'
radius = 750
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, 
                                                                            CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ecff7fd0be7b4001b5399a5'},
#  'response': {'venues': [{'id': '5414a874498ef49ca335992d',
#     'name': 'Carribean Roti',
#     'location': {'lat': 43.658216187158324,
#      'lng': -79.38226093721481,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.658216187158324,
#        'lng': -79.38226093721481}],
#      'distance': 544,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d144941735',
#       'name': 'Caribbean Restaurant',
#       'pluralName': 'Caribbean Restaurants',
#       'shortName': 'Caribbean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/caribbean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '4ad4c05ff964a52048f720e3',
#     'name': 'Hemispheres Restaurant & Bistro',
#     'location': {'address': '110 Chestnut Street',
#      'lat': 43.65488413420439,
#      'lng': -79.38593077371578,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65488413420439,
#        'lng': -79.38593077371578}],
#      'distance': 224,
#      'postalCode': 'M5G 1R3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['110 Chestnut Street',
#       'Toronto ON M5G 1R3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '4cffc78a75d3236a3b10e7f7',
#     'name': 'Osgoode Hall Restaurant',
#     'location': {'address': '130 Queen St W',
#      'crossStreet': 'University Ave',
#      'lat': 43.651978959035155,
#      'lng': -79.3850485857013,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.651978959035155,
#        'lng': -79.3850485857013}],
#      'distance': 189,
#      'postalCode': 'M5H 2N6',
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['130 Queen St W (University Ave)',
#       'M5H 2N6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d157941735',
#       'name': 'New American Restaurant',
#       'pluralName': 'New American Restaurants',
#       'shortName': 'New American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '4ad896f0f964a520981221e3',
#     'name': 'Caribbean Queen',
#     'location': {'address': '10 Dundas St E',
#      'crossStreet': 'at Yonge St',
#      'lat': 43.6563137870131,
#      'lng': -79.38095936571834,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6563137870131,
#        'lng': -79.38095936571834}],
#      'distance': 396,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['10 Dundas St E (at Yonge St)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d144941735',
#       'name': 'Caribbean Restaurant',
#       'pluralName': 'Caribbean Restaurants',
#       'shortName': 'Caribbean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/caribbean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '4c476d6719fde21e32410876',
#     'name': 'Cali Restaurant',
#     'location': {'address': '179 Dundas St. W.',
#      'crossStreet': 'at Chestnut',
#      'lat': 43.65506808,
#      'lng': -79.386375,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65506808,
#        'lng': -79.386375}],
#      'distance': 264,
#      'postalCode': 'M5G',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['179 Dundas St. W. (at Chestnut)',
#       'Toronto ON M5G',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'shortName': 'Vietnamese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '4c69740b8d22c9284d42b745',
#     'name': 'Wah Too Seafood Restaurant',
#     'location': {'address': '56 Centre Ave.',
#      'lat': 43.65483285234745,
#      'lng': -79.38720597193928,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65483285234745,
#        'lng': -79.38720597193928}],
#      'distance': 303,
#      'postalCode': 'M5G 1R5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['56 Centre Ave.', 'Toronto ON M5G 1R5', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '52a7ae41498eed3af4d0a3fa',
#     'name': 'Yueh Tung Chinese Restaurant',
#     'location': {'address': '126 Elizabeth St.',
#      'crossStreet': 'Dundas St.',
#      'lat': 43.655281263429195,
#      'lng': -79.3853365267765,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.655281263429195,
#        'lng': -79.3853365267765}],
#      'distance': 229,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['126 Elizabeth St. (Dundas St.)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '4b295e10f964a520ba9d24e3',
#     'name': 'Richtree Natural Market Restaurants',
#     'location': {'address': '14 Queen St W',
#      'lat': 43.652614361741726,
#      'lng': -79.38023131683906,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.652614361741726,
#        'lng': -79.38023131683906}],
#      'distance': 313,
#      'postalCode': 'M5H 3X4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['14 Queen St W', 'Toronto ON M5H 3X4', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '5750b013498e755287c6de97',
#     'name': 'Some Time BBQ Grill Restaurant 碳烤屋',
#     'location': {'address': '988 Baldwin Street',
#      'lat': 43.655874,
#      'lng': -79.393826,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.655874,
#        'lng': -79.393826}],
#      'distance': 839,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['988 Baldwin Street', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '52af3b773cf9994f4e043c03',
#       'name': 'Szechuan Restaurant',
#       'pluralName': 'Szechuan Restaurants',
#       'shortName': 'Szechuan',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '4b2a674ef964a52074a824e3',
#     'name': 'New Treasure Restaurant',
#     'location': {'address': '150 Dundas St W',
#      'crossStreet': 'at Elizabeth',
#      'lat': 43.65538444237565,
#      'lng': -79.3853618106867,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65538444237565,
#        'lng': -79.3853618106867}],
#      'distance': 240,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['150 Dundas St W (at Elizabeth)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1f5931735',
#       'name': 'Dim Sum Restaurant',
#       'pluralName': 'Dim Sum Restaurants',
#       'shortName': 'Dim Sum',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dimsum_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '4ad4c060f964a5205cf720e3',
#     'name': 'Lai Wah Heen',
#     'location': {'address': '108 Chestnut St.',
#      'crossStreet': 'Chestnut St & Dundas St',
#      'lat': 43.65503785867478,
#      'lng': -79.38589043402241,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65503785867478,
#        'lng': -79.38589043402241}],
#      'distance': 234,
#      'postalCode': 'M5G 1R3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['108 Chestnut St. (Chestnut St & Dundas St)',
#       'Toronto ON M5G 1R3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '4ddd83c788779c82beb061fc',
#     'name': "Ali Baba's",
#     'location': {'address': '199 Dundas St. W',
#      'crossStreet': 'at Centre Ave.',
#      'lat': 43.65491647880546,
#      'lng': -79.38717216891472,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65491647880546,
#        'lng': -79.38717216891472}],
#      'distance': 305,
#      'postalCode': 'M5g 1c8',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['199 Dundas St. W (at Centre Ave.)',
#       'Toronto ON M5g 1c8',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d115941735',
#       'name': 'Middle Eastern Restaurant',
#       'pluralName': 'Middle Eastern Restaurants',
#       'shortName': 'Middle Eastern',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '4ad4c05cf964a52006f620e3',
#     'name': "Victoria's Restaurant",
#     'location': {'address': '37 King Street East',
#      'crossStreet': 'at Le Meridien King Edward Hotel',
#      'lat': 43.64929834396347,
#      'lng': -79.37643067251867,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64929834396347,
#        'lng': -79.37643067251867}],
#      'distance': 763,
#      'postalCode': 'M5C 1E9',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['37 King Street East (at Le Meridien King Edward Hotel)',
#       'Toronto ON M5C 1E9',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '498556908'},
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '4beb2c0ba9900f475b7a1740',
#     'name': 'Ninki Sushi',
#     'location': {'address': '40 King St W',
#      'crossStreet': 'at Bay St',
#      'lat': 43.649812174244005,
#      'lng': -79.37951837924346,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.649812174244005,
#        'lng': -79.37951837924346}],
#      'distance': 541,
#      'postalCode': 'M5H 1A1',
#      'cc': 'CA',
#      'neighborhood': 'Financial District',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['40 King St W (at Bay St)',
#       'Toronto ON M5H 1A1',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '4ae4b055f964a520229d21e3',
#     'name': 'Kyoto House Japanese Restaurant',
#     'location': {'address': '143 Dundas St. West',
#      'lat': 43.65538110598594,
#      'lng': -79.38527010094231,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65538110598594,
#        'lng': -79.38527010094231}],
#      'distance': 237,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['143 Dundas St. West', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '53ae6660498e1ac3c1282743',
#     'name': 'Castries Bar & Five Way Restaurant',
#     'location': {'lat': 43.654727935791016,
#      'lng': -79.38092803955078,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654727935791016,
#        'lng': -79.38092803955078}],
#      'distance': 279,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d144941735',
#       'name': 'Caribbean Restaurant',
#       'pluralName': 'Caribbean Restaurants',
#       'shortName': 'Caribbean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/caribbean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '4b2027b5f964a520f82d24e3',
#     'name': 'Hong Shing Chinese Restaurant',
#     'location': {'address': '195 Dundas St W',
#      'crossStreet': 'at University Ave',
#      'lat': 43.65492521335936,
#      'lng': -79.38708916106386,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65492521335936,
#        'lng': -79.38708916106386}],
#      'distance': 300,
#      'postalCode': 'M5G 1C7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['195 Dundas St W (at University Ave)',
#       'Toronto ON M5G 1C7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '60327598'},
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '4adc5c6af964a520da2b21e3',
#     'name': 'Mercatto',
#     'location': {'address': '330 Bay St.',
#      'crossStreet': 'btwn Temperance & Adelaide',
#      'lat': 43.6502431921682,
#      'lng': -79.38081989149896,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6502431921682,
#        'lng': -79.38081989149896}],
#      'distance': 439,
#      'postalCode': 'M5H 2S8',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['330 Bay St. (btwn Temperance & Adelaide)',
#       'Toronto ON M5H 2S8',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '5834c90e110d032f3217f899',
#     'name': 'Maezo Restaurant & Bar',
#     'location': {'address': '67 Richmond Street West',
#      'crossStreet': 'Richmond and Bay Street',
#      'lat': 43.651090520885205,
#      'lng': -79.38184261322021,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.651090520885205,
#        'lng': -79.38184261322021}],
#      'distance': 315,
#      'postalCode': 'M5H 1Z5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['67 Richmond Street West (Richmond and Bay Street)',
#       'Toronto ON M5H 1Z5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '369067217'},
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '4ed5094f0e01fd2f5bc0190f',
#     'name': 'A&W',
#     'location': {'address': '1 Richmond Street West',
#      'lat': 43.651378,
#      'lng': -79.378986,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.651378,
#        'lng': -79.378986}],
#      'distance': 462,
#      'postalCode': 'M5H 3W4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['1 Richmond Street West',
#       'Toronto ON M5H 3W4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '4af63562f964a5203d0222e3',
#     'name': 'Bikkuri Japanese',
#     'location': {'address': '36 King St. E',
#      'crossStreet': 'at Victoria',
#      'lat': 43.649564308142,
#      'lng': -79.37632789169632,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.649564308142,
#        'lng': -79.37632789169632}],
#      'distance': 752,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['36 King St. E (at Victoria)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '4fbbb3ace4b01e39077b4d55',
#     'name': 'Akashiro Japanese Restaurant & Bar',
#     'location': {'address': '220 Yonge St.',
#      'crossStreet': 'in Toronto Eaton Centre Urban Eatery',
#      'lat': 43.65596504293232,
#      'lng': -79.38054070644233,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65596504293232,
#        'lng': -79.38054070644233}],
#      'distance': 388,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['220 Yonge St. (in Toronto Eaton Centre Urban Eatery)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '5a8b24b2018cbb6c4ca70dae',
#     'name': 'Hendricks Restaurant & Bar',
#     'location': {'address': 'Yonge And Queen',
#      'crossStreet': 'Queen St',
#      'lat': 43.65341542752959,
#      'lng': -79.37969842137554,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65341542752959,
#        'lng': -79.37969842137554}],
#      'distance': 341,
#      'postalCode': 'M5G 2H6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Yonge And Queen (Queen St)',
#       'Toronto ON M5G 2H6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '4b223f5af964a520ba4424e3',
#     'name': 'Azure Restaurant & Bar',
#     'location': {'address': '225 Front St W',
#      'crossStreet': 'in InterContinental Toronto Centre',
#      'lat': 43.644749195919346,
#      'lng': -79.38511295085902,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.644749195919346,
#        'lng': -79.38511295085902}],
#      'distance': 976,
#      'postalCode': 'M5V 2X3',
#      'cc': 'CA',
#      'neighborhood': 'Entertainment District',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['225 Front St W (in InterContinental Toronto Centre)',
#       'Toronto ON M5V 2X3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '136175835'},
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '4b86c8d6f964a5201b9d31e3',
#     'name': 'Subway',
#     'location': {'address': '33 University Ave, Unit 2',
#      'crossStreet': 'at Wellington St W',
#      'lat': 43.64620942980489,
#      'lng': -79.38359506100971,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64620942980489,
#        'lng': -79.38359506100971}],
#      'distance': 810,
#      'postalCode': 'M5J 2S7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['33 University Ave, Unit 2 (at Wellington St W)',
#       'Toronto ON M5J 2S7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '4afb1ff7f964a5205b1b22e3',
#     'name': 'Spring Rolls',
#     'location': {'address': '40 Dundas St. W',
#      'crossStreet': 'at Yonge St.',
#      'lat': 43.655997379987994,
#      'lng': -79.38245534190555,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.655997379987994,
#        'lng': -79.38245534190555}],
#      'distance': 304,
#      'postalCode': 'M5G 2C2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['40 Dundas St. W (at Yonge St.)',
#       'Toronto ON M5G 2C2',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '4b82c671f964a52016e430e3',
#     'name': 'Anoush Restaurant',
#     'location': {'address': '250 Dundas St W',
#      'lat': 43.654588,
#      'lng': -79.389692,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654588,
#        'lng': -79.389692}],
#      'distance': 479,
#      'postalCode': 'M5T 2Z5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['250 Dundas St W', 'Toronto ON M5T 2Z5', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '4afa1f33f964a520e91622e3',
#     'name': 'Fune Japanese Restaurant',
#     'location': {'address': '100 Simcoe St.',
#      'crossStreet': 'at Pearl St.',
#      'lat': 43.64851365544565,
#      'lng': -79.38645657820041,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64851365544565,
#        'lng': -79.38645657820041}],
#      'distance': 589,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['100 Simcoe St. (at Pearl St.)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '4ad4c061f964a52095f720e3',
#     'name': 'Salad King',
#     'location': {'address': '340 Yonge St',
#      'crossStreet': 'at Gould St',
#      'lat': 43.65760101432665,
#      'lng': -79.38161963017174,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65760101432665,
#        'lng': -79.38161963017174}],
#      'distance': 495,
#      'postalCode': 'M5B 1R7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['340 Yonge St (at Gould St)',
#       'Toronto ON M5B 1R7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '5b7618541ffe97002c1a13ae',
#     'name': 'Maezo Restaurant',
#     'location': {'address': '67 Richmond St West',
#      'lat': 43.6513954168839,
#      'lng': -79.38188786532692,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6513954168839,
#        'lng': -79.38188786532692}],
#      'distance': 284,
#      'postalCode': 'M5H 1W2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['67 Richmond St West',
#       'Toronto ON M5H 1W2',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '4ad4c05df964a52059f620e3',
#     'name': 'Canoe',
#     'location': {'address': '66 Wellington St West',
#      'crossStreet': 'at Bay Street',
#      'lat': 43.647452066183476,
#      'lng': -79.38132001815676,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.647452066183476,
#        'lng': -79.38132001815676}],
#      'distance': 703,
#      'postalCode': 'M5K 1H6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['66 Wellington St West (at Bay Street)',
#       'Toronto ON M5K 1H6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '40552945'},
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '56dd9d68498eb4e5edcb30f9',
#     'name': 'Spring Rolls | Japanese Restaurant in Toronto',
#     'location': {'address': '40 Dundas St W Box 36,',
#      'lat': 43.65610515821675,
#      'lng': -79.38349485397339,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65610515821675,
#        'lng': -79.38349485397339}],
#      'distance': 294,
#      'postalCode': 'M5G 2C2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['40 Dundas St W Box 36,',
#       'Toronto ON M5G 2C2',
#       'Canada']},
#     'categories': [{'id': '56aa371be4b08b9a8d573538',
#       'name': 'Theme Restaurant',
#       'pluralName': 'Theme Restaurants',
#       'shortName': 'Theme Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '532063ce498e106a873aa20b',
#     'name': 'City Kitchen',
#     'location': {'address': '220 Yonge Street',
#      'lat': 43.65401783830981,
#      'lng': -79.37982648714211,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65401783830981,
#        'lng': -79.37982648714211}],
#      'distance': 336,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['220 Yonge Street', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '4de827e4d4c0faa56428a51a',
#     'name': 'Yulla Asian Fusion Restaurant',
#     'location': {'lat': 43.651587,
#      'lng': -79.379232,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.651587,
#        'lng': -79.379232}],
#      'distance': 433,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '4c6abb8c2c29d13ad2720e41',
#     'name': 'Subway',
#     'location': {'address': '10 Dundas St E, No 337',
#      'crossStreet': 'at Yonge St.',
#      'lat': 43.6564939,
#      'lng': -79.3807983,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6564939,
#        'lng': -79.3807983}],
#      'distance': 419,
#      'postalCode': 'M5B 2G9',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['10 Dundas St E, No 337 (at Yonge St.)',
#       'Toronto ON M5B 2G9',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '4c38f3fc0a71c9b6f6ad41c9',
#     'name': 'B.L.D Restaurant',
#     'location': {'address': '36 Toronto St',
#      'crossStreet': 'Adelaide',
#      'lat': 43.6508315945072,
#      'lng': -79.37663892404116,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6508315945072,
#        'lng': -79.37663892404116}],
#      'distance': 657,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['36 Toronto St (Adelaide)', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d157941735',
#       'name': 'New American Restaurant',
#       'pluralName': 'New American Restaurants',
#       'shortName': 'New American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '4ad8a5a7f964a5203c1321e3',
#     'name': 'Little India Restaurant',
#     'location': {'address': '255 Queen St. W',
#      'crossStreet': 'Queen and University',
#      'lat': 43.65031880877208,
#      'lng': -79.38899760320798,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65031880877208,
#        'lng': -79.38899760320798}],
#      'distance': 538,
#      'postalCode': 'M5V 1Z4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['255 Queen St. W (Queen and University)',
#       'Toronto ON M5V 1Z4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '57793907'},
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '4df909dfe4cd2129701c0690',
#     'name': 'JOEY Eaton Centre',
#     'location': {'address': '1 Dundas St W',
#      'lat': 43.6560936540828,
#      'lng': -79.38187792357716,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6560936540828,
#        'lng': -79.38187792357716}],
#      'distance': 334,
#      'postalCode': 'M5G 1Z3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['1 Dundas St W', 'Toronto ON M5G 1Z3', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d157941735',
#       'name': 'New American Restaurant',
#       'pluralName': 'New American Restaurants',
#       'shortName': 'New American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '4ad7929cf964a520500c21e3',
#     'name': 'The Senator Restaurant',
#     'location': {'address': '249 Victoria Street',
#      'crossStreet': 'btwn Dundas St E and Shuter St',
#      'lat': 43.65564091455335,
#      'lng': -79.37919882575557,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65564091455335,
#        'lng': -79.37919882575557}],
#      'distance': 450,
#      'postalCode': 'M5B 1T8',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['249 Victoria Street (btwn Dundas St E and Shuter St)',
#       'Toronto ON M5B 1T8',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d147941735',
#       'name': 'Diner',
#       'pluralName': 'Diners',
#       'shortName': 'Diner',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '55585058'},
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '4edbccaaf9abeea3db5268df',
#     'name': 'Terrace Restaurant at Elmwood',
#     'location': {'lat': 43.65610066909799,
#      'lng': -79.38148016065777,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65610066909799,
#        'lng': -79.38148016065777}],
#      'distance': 352,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '4ada04eff964a520571d21e3',
#     'name': "Fran's",
#     'location': {'address': '200 Victoria St',
#      'crossStreet': 'at Shuter St',
#      'lat': 43.65426474929814,
#      'lng': -79.37912005538317,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65426474929814,
#        'lng': -79.37912005538317}],
#      'distance': 397,
#      'postalCode': 'M5B 2R3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['200 Victoria St (at Shuter St)',
#       'Toronto ON M5B 2R3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d147941735',
#       'name': 'Diner',
#       'pluralName': 'Diners',
#       'shortName': 'Diner',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '4b999927f964a5207c8635e3',
#     'name': 'NAMI',
#     'location': {'address': '55 Adelaide Street East',
#      'crossStreet': 'at Church street',
#      'lat': 43.650853361785124,
#      'lng': -79.37588746641697,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.650853361785124,
#        'lng': -79.37588746641697}],
#      'distance': 711,
#      'postalCode': 'M5C 1K6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['55 Adelaide Street East (at Church street)',
#       'Toronto ON M5C 1K6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '4b231e82f964a5208e5324e3',
#     'name': 'Stratus',
#     'location': {'address': '79 Wellington St W',
#      'crossStreet': 'at Piper St',
#      'lat': 43.64618144730835,
#      'lng': -79.38080934737143,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64618144730835,
#        'lng': -79.38080934737143}],
#      'distance': 850,
#      'postalCode': 'M5K 1J5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['79 Wellington St W (at Piper St)',
#       'Toronto ON M5K 1J5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '4ad4c060f964a52057f720e3',
#     'name': 'Jump',
#     'location': {'address': '18 Wellington St. W',
#      'crossStreet': 'btwn. Yonge St. and Bay St.',
#      'lat': 43.64814738516352,
#      'lng': -79.37875242540652,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64814738516352,
#        'lng': -79.37875242540652}],
#      'distance': 725,
#      'postalCode': 'M5L 1G4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['18 Wellington St. W (btwn. Yonge St. and Bay St.)',
#       'Toronto ON M5L 1G4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '41473022'},
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '5c636fa1492814002c0cb117',
#     'name': 'Cru Restaurant',
#     'location': {'address': '100 Yonge St',
#      'crossStreet': 'Yonge and King',
#      'lat': 43.64982,
#      'lng': -79.37835,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64982,
#        'lng': -79.37835}],
#      'distance': 607,
#      'postalCode': 'M5C 2W1',
#      'cc': 'CA',
#      'neighborhood': 'Financial District',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['100 Yonge St (Yonge and King)',
#       'Toronto ON M5C 2W1',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '4ae31ac7f964a520799021e3',
#     'name': 'East Restaurant Asian Street Flair',
#     'location': {'address': '240 Queen Street West',
#      'crossStreet': 'Queen and John',
#      'lat': 43.64998452583986,
#      'lng': -79.39056268913188,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64998452583986,
#        'lng': -79.39056268913188}],
#      'distance': 660,
#      'postalCode': 'M5v1z7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['240 Queen Street West (Queen and John)',
#       'Toronto ON M5v1z7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '4b06e099f964a52002f222e3',
#     'name': 'Over Easy',
#     'location': {'address': '56 Yonge St',
#      'crossStreet': 'at Melinda St',
#      'lat': 43.64807704204346,
#      'lng': -79.37759871575396,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64807704204346,
#        'lng': -79.37759871575396}],
#      'distance': 788,
#      'postalCode': 'M5E 1G5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['56 Yonge St (at Melinda St)',
#       'Toronto ON M5E 1G5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d143941735',
#       'name': 'Breakfast Spot',
#       'pluralName': 'Breakfast Spots',
#       'shortName': 'Breakfast',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '4ae73054f964a5203ca921e3',
#     'name': 'Ki Modern Japanese + Bar',
#     'location': {'address': '181 Bay St',
#      'crossStreet': 'at Wellington St. W',
#      'lat': 43.647167,
#      'lng': -79.379608,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.647167,
#        'lng': -79.379608}],
#      'distance': 784,
#      'postalCode': 'M5J 2T3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['181 Bay St (at Wellington St. W)',
#       'Toronto ON M5J 2T3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '50ca02be245f2d4aa8c2ab5b',
#     'name': 'Barristers Bar',
#     'location': {'address': '145 Richmond Street West',
#      'crossStreet': 'Hilton Toronto',
#      'lat': 43.64979669604817,
#      'lng': -79.3858073393927,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64979669604817,
#        'lng': -79.3858073393927}],
#      'distance': 437,
#      'postalCode': 'M5H 2L2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['145 Richmond Street West (Hilton Toronto)',
#       'Toronto ON M5H 2L2',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590687750',
#     'hasPerk': False},
#    {'id': '4ae9ef82f964a520cbb721e3',
#     'name': 'Alio Restaurant & Wine Bar',
#     'location': {'address': '108 Dundas St W',
#      'crossStreet': 'at Bay St.',
#      'lat': 43.65565507065502,
#      'lng': -79.3841236014983,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65565507065502,
#        'lng': -79.3841236014983}],
#      'distance': 242,
#      'postalCode': 'M5G 1C3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['108 Dundas St W (at Bay St.)',
#       'Toronto ON M5G 1C3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590687750',
#     'hasPerk': False}]}}

# %%
venues = results['response']['venues']
dataframe = json_normalize(venues)
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]
dataframe_filtered
# Out:
#                                              name                 categories  \
# 0                                  Carribean Roti       Caribbean Restaurant
# 1                 Hemispheres Restaurant & Bistro        American Restaurant
# 2                         Osgoode Hall Restaurant    New American Restaurant
# 3                                 Caribbean Queen       Caribbean Restaurant
# 4                                 Cali Restaurant      Vietnamese Restaurant
# 5                      Wah Too Seafood Restaurant         Chinese Restaurant
# 6                    Yueh Tung Chinese Restaurant         Chinese Restaurant
# 7             Richtree Natural Market Restaurants                 Restaurant
# 8              Some Time BBQ Grill Restaurant 碳烤屋        Szechuan Restaurant
# 9                         New Treasure Restaurant         Dim Sum Restaurant
# 10                                   Lai Wah Heen         Chinese Restaurant
# 11                                     Ali Baba's  Middle Eastern Restaurant
# 12                          Victoria's Restaurant                 Restaurant
# 13                                    Ninki Sushi        Japanese Restaurant
# 14                Kyoto House Japanese Restaurant           Sushi Restaurant
# 15             Castries Bar & Five Way Restaurant       Caribbean Restaurant
# 16                  Hong Shing Chinese Restaurant         Chinese Restaurant
# 17                                       Mercatto         Italian Restaurant
# 18                         Maezo Restaurant & Bar          Indian Restaurant
# 19                                            A&W       Fast Food Restaurant
# 20                               Bikkuri Japanese           Sushi Restaurant
# 21             Akashiro Japanese Restaurant & Bar           Sushi Restaurant
# 22                     Hendricks Restaurant & Bar                 Restaurant
# 23                         Azure Restaurant & Bar                 Restaurant
# 24                                         Subway             Sandwich Place
# 25                                   Spring Rolls           Asian Restaurant
# 26                              Anoush Restaurant                 Restaurant
# 27                       Fune Japanese Restaurant        Japanese Restaurant
# 28                                     Salad King            Thai Restaurant
# 29                               Maezo Restaurant          Indian Restaurant
# 30                                          Canoe                 Restaurant
# 31  Spring Rolls | Japanese Restaurant in Toronto           Theme Restaurant
# 32                                   City Kitchen                 Restaurant
# 33                  Yulla Asian Fusion Restaurant           Asian Restaurant
# 34                                         Subway             Sandwich Place
# 35                               B.L.D Restaurant    New American Restaurant
# 36                        Little India Restaurant          Indian Restaurant
# 37                              JOEY Eaton Centre    New American Restaurant
# 38                         The Senator Restaurant                      Diner
# 39                  Terrace Restaurant at Elmwood        American Restaurant
# 40                                         Fran's                      Diner
# 41                                           NAMI        Japanese Restaurant
# 42                                        Stratus                 Restaurant
# 43                                           Jump        American Restaurant
# 44                                 Cru Restaurant                 Restaurant
# 45             East Restaurant Asian Street Flair           Asian Restaurant
# 46                                      Over Easy             Breakfast Spot
# 47                       Ki Modern Japanese + Bar        Japanese Restaurant
# 48                                 Barristers Bar                 Restaurant
# 49                     Alio Restaurant & Wine Bar         Italian Restaurant
#
#                       address  cc     city country  \
# 0                         NaN  CA      NaN  Canada
# 1         110 Chestnut Street  CA  Toronto  Canada
# 2              130 Queen St W  CA      NaN  Canada
# 3              10 Dundas St E  CA  Toronto  Canada
# 4           179 Dundas St. W.  CA  Toronto  Canada
# 5              56 Centre Ave.  CA  Toronto  Canada
# 6           126 Elizabeth St.  CA  Toronto  Canada
# 7               14 Queen St W  CA  Toronto  Canada
# 8          988 Baldwin Street  CA  Toronto  Canada
# 9             150 Dundas St W  CA  Toronto  Canada
# 10           108 Chestnut St.  CA  Toronto  Canada
# 11           199 Dundas St. W  CA  Toronto  Canada
# 12        37 King Street East  CA  Toronto  Canada
# 13               40 King St W  CA  Toronto  Canada
# 14        143 Dundas St. West  CA  Toronto  Canada
# 15                        NaN  CA      NaN  Canada
# 16            195 Dundas St W  CA  Toronto  Canada
# 17                330 Bay St.  CA  Toronto  Canada
# 18    67 Richmond Street West  CA  Toronto  Canada
# 19     1 Richmond Street West  CA  Toronto  Canada
# 20              36 King St. E  CA  Toronto  Canada
# 21              220 Yonge St.  CA  Toronto  Canada
# 22            Yonge And Queen  CA  Toronto  Canada
# 23             225 Front St W  CA  Toronto  Canada
# 24  33 University Ave, Unit 2  CA  Toronto  Canada
# 25            40 Dundas St. W  CA  Toronto  Canada
# 26            250 Dundas St W  CA  Toronto  Canada
# 27             100 Simcoe St.  CA  Toronto  Canada
# 28               340 Yonge St  CA  Toronto  Canada
# 29        67 Richmond St West  CA  Toronto  Canada
# 30      66 Wellington St West  CA  Toronto  Canada
# 31     40 Dundas St W Box 36,  CA  Toronto  Canada
# 32           220 Yonge Street  CA  Toronto  Canada
# 33                        NaN  CA  Toronto  Canada
# 34     10 Dundas St E, No 337  CA  Toronto  Canada
# 35              36 Toronto St  CA  Toronto  Canada
# 36            255 Queen St. W  CA  Toronto  Canada
# 37              1 Dundas St W  CA  Toronto  Canada
# 38        249 Victoria Street  CA  Toronto  Canada
# 39                        NaN  CA      NaN  Canada
# 40            200 Victoria St  CA  Toronto  Canada
# 41    55 Adelaide Street East  CA  Toronto  Canada
# 42         79 Wellington St W  CA  Toronto  Canada
# 43        18 Wellington St. W  CA  Toronto  Canada
# 44               100 Yonge St  CA  Toronto  Canada
# 45      240 Queen Street West  CA  Toronto  Canada
# 46                56 Yonge St  CA  Toronto  Canada
# 47                 181 Bay St  CA  Toronto  Canada
# 48   145 Richmond Street West  CA  Toronto  Canada
# 49            108 Dundas St W  CA  Toronto  Canada
#
#                              crossStreet  distance  \
# 0                                    NaN       544
# 1                                    NaN       224
# 2                         University Ave       189
# 3                            at Yonge St       396
# 4                            at Chestnut       264
# 5                                    NaN       303
# 6                             Dundas St.       229
# 7                                    NaN       313
# 8                                    NaN       839
# 9                           at Elizabeth       240
# 10               Chestnut St & Dundas St       234
# 11                        at Centre Ave.       305
# 12      at Le Meridien King Edward Hotel       763
# 13                             at Bay St       541
# 14                                   NaN       237
# 15                                   NaN       279
# 16                     at University Ave       300
# 17            btwn Temperance & Adelaide       439
# 18               Richmond and Bay Street       315
# 19                                   NaN       462
# 20                           at Victoria       752
# 21  in Toronto Eaton Centre Urban Eatery       388
# 22                              Queen St       341
# 23    in InterContinental Toronto Centre       976
# 24                    at Wellington St W       810
# 25                          at Yonge St.       304
# 26                                   NaN       479
# 27                          at Pearl St.       589
# 28                           at Gould St       495
# 29                                   NaN       284
# 30                         at Bay Street       703
# 31                                   NaN       294
# 32                                   NaN       336
# 33                                   NaN       433
# 34                          at Yonge St.       419
# 35                              Adelaide       657
# 36                  Queen and University       538
# 37                                   NaN       334
# 38        btwn Dundas St E and Shuter St       450
# 39                                   NaN       352
# 40                          at Shuter St       397
# 41                      at Church street       711
# 42                           at Piper St       850
# 43           btwn. Yonge St. and Bay St.       725
# 44                        Yonge and King       607
# 45                        Queen and John       660
# 46                         at Melinda St       788
# 47                   at Wellington St. W       784
# 48                        Hilton Toronto       437
# 49                            at Bay St.       242
#
#                                      formattedAddress  \
# 0                                            [Canada]
# 1   [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 2   [130 Queen St W (University Ave), M5H 2N6, Can...
# 3   [10 Dundas St E (at Yonge St), Toronto ON, Can...
# 4   [179 Dundas St. W. (at Chestnut), Toronto ON M...
# 5        [56 Centre Ave., Toronto ON M5G 1R5, Canada]
# 6   [126 Elizabeth St. (Dundas St.), Toronto ON, C...
# 7         [14 Queen St W, Toronto ON M5H 3X4, Canada]
# 8            [988 Baldwin Street, Toronto ON, Canada]
# 9   [150 Dundas St W (at Elizabeth), Toronto ON, C...
# 10  [108 Chestnut St. (Chestnut St & Dundas St), T...
# 11  [199 Dundas St. W (at Centre Ave.), Toronto ON...
# 12  [37 King Street East (at Le Meridien King Edwa...
# 13  [40 King St W (at Bay St), Toronto ON M5H 1A1,...
# 14          [143 Dundas St. West, Toronto ON, Canada]
# 15                                           [Canada]
# 16  [195 Dundas St W (at University Ave), Toronto ...
# 17  [330 Bay St. (btwn Temperance & Adelaide), Tor...
# 18  [67 Richmond Street West (Richmond and Bay Str...
# 19  [1 Richmond Street West, Toronto ON M5H 3W4, C...
# 20  [36 King St. E (at Victoria), Toronto ON, Canada]
# 21  [220 Yonge St. (in Toronto Eaton Centre Urban ...
# 22  [Yonge And Queen (Queen St), Toronto ON M5G 2H...
# 23  [225 Front St W (in InterContinental Toronto C...
# 24  [33 University Ave, Unit 2 (at Wellington St W...
# 25  [40 Dundas St. W (at Yonge St.), Toronto ON M5...
# 26      [250 Dundas St W, Toronto ON M5T 2Z5, Canada]
# 27  [100 Simcoe St. (at Pearl St.), Toronto ON, Ca...
# 28  [340 Yonge St (at Gould St), Toronto ON M5B 1R...
# 29  [67 Richmond St West, Toronto ON M5H 1W2, Canada]
# 30  [66 Wellington St West (at Bay Street), Toront...
# 31  [40 Dundas St W Box 36,, Toronto ON M5G 2C2, C...
# 32             [220 Yonge Street, Toronto ON, Canada]
# 33                               [Toronto ON, Canada]
# 34  [10 Dundas St E, No 337 (at Yonge St.), Toront...
# 35     [36 Toronto St (Adelaide), Toronto ON, Canada]
# 36  [255 Queen St. W (Queen and University), Toron...
# 37        [1 Dundas St W, Toronto ON M5G 1Z3, Canada]
# 38  [249 Victoria Street (btwn Dundas St E and Shu...
# 39                                           [Canada]
# 40  [200 Victoria St (at Shuter St), Toronto ON M5...
# 41  [55 Adelaide Street East (at Church street), T...
# 42  [79 Wellington St W (at Piper St), Toronto ON ...
# 43  [18 Wellington St. W (btwn. Yonge St. and Bay ...
# 44  [100 Yonge St (Yonge and King), Toronto ON M5C...
# 45  [240 Queen Street West (Queen and John), Toron...
# 46  [56 Yonge St (at Melinda St), Toronto ON M5E 1...
# 47  [181 Bay St (at Wellington St. W), Toronto ON ...
# 48  [145 Richmond Street West (Hilton Toronto), To...
# 49  [108 Dundas St W (at Bay St.), Toronto ON M5G ...
#
#                                        labeledLatLngs        lat        lng  \
# 0   [{'label': 'display', 'lat': 43.65821618715832...  43.658216 -79.382261
# 1   [{'label': 'display', 'lat': 43.65488413420439...  43.654884 -79.385931
# 2   [{'label': 'display', 'lat': 43.65197895903515...  43.651979 -79.385049
# 3   [{'label': 'display', 'lat': 43.6563137870131,...  43.656314 -79.380959
# 4   [{'label': 'display', 'lat': 43.65506808, 'lng...  43.655068 -79.386375
# 5   [{'label': 'display', 'lat': 43.65483285234745...  43.654833 -79.387206
# 6   [{'label': 'display', 'lat': 43.65528126342919...  43.655281 -79.385337
# 7   [{'label': 'display', 'lat': 43.65261436174172...  43.652614 -79.380231
# 8   [{'label': 'display', 'lat': 43.655874, 'lng':...  43.655874 -79.393826
# 9   [{'label': 'display', 'lat': 43.65538444237565...  43.655384 -79.385362
# 10  [{'label': 'display', 'lat': 43.65503785867478...  43.655038 -79.385890
# 11  [{'label': 'display', 'lat': 43.65491647880546...  43.654916 -79.387172
# 12  [{'label': 'display', 'lat': 43.64929834396347...  43.649298 -79.376431
# 13  [{'label': 'display', 'lat': 43.64981217424400...  43.649812 -79.379518
# 14  [{'label': 'display', 'lat': 43.65538110598594...  43.655381 -79.385270
# 15  [{'label': 'display', 'lat': 43.65472793579101...  43.654728 -79.380928
# 16  [{'label': 'display', 'lat': 43.65492521335936...  43.654925 -79.387089
# 17  [{'label': 'display', 'lat': 43.6502431921682,...  43.650243 -79.380820
# 18  [{'label': 'display', 'lat': 43.65109052088520...  43.651091 -79.381843
# 19  [{'label': 'display', 'lat': 43.651378, 'lng':...  43.651378 -79.378986
# 20  [{'label': 'display', 'lat': 43.649564308142, ...  43.649564 -79.376328
# 21  [{'label': 'display', 'lat': 43.65596504293232...  43.655965 -79.380541
# 22  [{'label': 'display', 'lat': 43.65341542752959...  43.653415 -79.379698
# 23  [{'label': 'display', 'lat': 43.64474919591934...  43.644749 -79.385113
# 24  [{'label': 'display', 'lat': 43.64620942980489...  43.646209 -79.383595
# 25  [{'label': 'display', 'lat': 43.65599737998799...  43.655997 -79.382455
# 26  [{'label': 'display', 'lat': 43.654588, 'lng':...  43.654588 -79.389692
# 27  [{'label': 'display', 'lat': 43.64851365544565...  43.648514 -79.386457
# 28  [{'label': 'display', 'lat': 43.65760101432665...  43.657601 -79.381620
# 29  [{'label': 'display', 'lat': 43.6513954168839,...  43.651395 -79.381888
# 30  [{'label': 'display', 'lat': 43.64745206618347...  43.647452 -79.381320
# 31  [{'label': 'display', 'lat': 43.65610515821675...  43.656105 -79.383495
# 32  [{'label': 'display', 'lat': 43.65401783830981...  43.654018 -79.379826
# 33  [{'label': 'display', 'lat': 43.651587, 'lng':...  43.651587 -79.379232
# 34  [{'label': 'display', 'lat': 43.6564939, 'lng'...  43.656494 -79.380798
# 35  [{'label': 'display', 'lat': 43.6508315945072,...  43.650832 -79.376639
# 36  [{'label': 'display', 'lat': 43.65031880877208...  43.650319 -79.388998
# 37  [{'label': 'display', 'lat': 43.6560936540828,...  43.656094 -79.381878
# 38  [{'label': 'display', 'lat': 43.65564091455335...  43.655641 -79.379199
# 39  [{'label': 'display', 'lat': 43.65610066909799...  43.656101 -79.381480
# 40  [{'label': 'display', 'lat': 43.65426474929814...  43.654265 -79.379120
# 41  [{'label': 'display', 'lat': 43.65085336178512...  43.650853 -79.375887
# 42  [{'label': 'display', 'lat': 43.64618144730835...  43.646181 -79.380809
# 43  [{'label': 'display', 'lat': 43.64814738516352...  43.648147 -79.378752
# 44  [{'label': 'display', 'lat': 43.64982, 'lng': ...  43.649820 -79.378350
# 45  [{'label': 'display', 'lat': 43.64998452583986...  43.649985 -79.390563
# 46  [{'label': 'display', 'lat': 43.64807704204346...  43.648077 -79.377599
# 47  [{'label': 'display', 'lat': 43.647167, 'lng':...  43.647167 -79.379608
# 48  [{'label': 'display', 'lat': 43.64979669604817...  43.649797 -79.385807
# 49  [{'label': 'display', 'lat': 43.65565507065502...  43.655655 -79.384124
#
#               neighborhood postalCode state                        id
# 0                      NaN        NaN   NaN  5414a874498ef49ca335992d
# 1                      NaN    M5G 1R3    ON  4ad4c05ff964a52048f720e3
# 2                      NaN    M5H 2N6   NaN  4cffc78a75d3236a3b10e7f7
# 3                      NaN        NaN    ON  4ad896f0f964a520981221e3
# 4                      NaN        M5G    ON  4c476d6719fde21e32410876
# 5                      NaN    M5G 1R5    ON  4c69740b8d22c9284d42b745
# 6                      NaN        NaN    ON  52a7ae41498eed3af4d0a3fa
# 7                      NaN    M5H 3X4    ON  4b295e10f964a520ba9d24e3
# 8                      NaN        NaN    ON  5750b013498e755287c6de97
# 9                      NaN        NaN    ON  4b2a674ef964a52074a824e3
# 10                     NaN    M5G 1R3    ON  4ad4c060f964a5205cf720e3
# 11                     NaN    M5g 1c8    ON  4ddd83c788779c82beb061fc
# 12                     NaN    M5C 1E9    ON  4ad4c05cf964a52006f620e3
# 13      Financial District    M5H 1A1    ON  4beb2c0ba9900f475b7a1740
# 14                     NaN        NaN    ON  4ae4b055f964a520229d21e3
# 15                     NaN        NaN   NaN  53ae6660498e1ac3c1282743
# 16                     NaN    M5G 1C7    ON  4b2027b5f964a520f82d24e3
# 17                     NaN    M5H 2S8    ON  4adc5c6af964a520da2b21e3
# 18                     NaN    M5H 1Z5    ON  5834c90e110d032f3217f899
# 19                     NaN    M5H 3W4    ON  4ed5094f0e01fd2f5bc0190f
# 20                     NaN        NaN    ON  4af63562f964a5203d0222e3
# 21                     NaN        NaN    ON  4fbbb3ace4b01e39077b4d55
# 22                     NaN    M5G 2H6    ON  5a8b24b2018cbb6c4ca70dae
# 23  Entertainment District    M5V 2X3    ON  4b223f5af964a520ba4424e3
# 24                     NaN    M5J 2S7    ON  4b86c8d6f964a5201b9d31e3
# 25                     NaN    M5G 2C2    ON  4afb1ff7f964a5205b1b22e3
# 26                     NaN    M5T 2Z5    ON  4b82c671f964a52016e430e3
# 27                     NaN        NaN    ON  4afa1f33f964a520e91622e3
# 28                     NaN    M5B 1R7    ON  4ad4c061f964a52095f720e3
# 29                     NaN    M5H 1W2    ON  5b7618541ffe97002c1a13ae
# 30                     NaN    M5K 1H6    ON  4ad4c05df964a52059f620e3
# 31                     NaN    M5G 2C2    ON  56dd9d68498eb4e5edcb30f9
# 32                     NaN        NaN    ON  532063ce498e106a873aa20b
# 33                     NaN        NaN    ON  4de827e4d4c0faa56428a51a
# 34                     NaN    M5B 2G9    ON  4c6abb8c2c29d13ad2720e41
# 35                     NaN        NaN    ON  4c38f3fc0a71c9b6f6ad41c9
# 36                     NaN    M5V 1Z4    ON  4ad8a5a7f964a5203c1321e3
# 37                     NaN    M5G 1Z3    ON  4df909dfe4cd2129701c0690
# 38                     NaN    M5B 1T8    ON  4ad7929cf964a520500c21e3
# 39                     NaN        NaN   NaN  4edbccaaf9abeea3db5268df
# 40                     NaN    M5B 2R3    ON  4ada04eff964a520571d21e3
# 41                     NaN    M5C 1K6    ON  4b999927f964a5207c8635e3
# 42                     NaN    M5K 1J5    ON  4b231e82f964a5208e5324e3
# 43                     NaN    M5L 1G4    ON  4ad4c060f964a52057f720e3
# 44      Financial District    M5C 2W1    ON  5c636fa1492814002c0cb117
# 45                     NaN     M5v1z7    ON  4ae31ac7f964a520799021e3
# 46                     NaN    M5E 1G5    ON  4b06e099f964a52002f222e3
# 47                     NaN    M5J 2T3    ON  4ae73054f964a5203ca921e3
# 48                     NaN    M5H 2L2    ON  50ca02be245f2d4aa8c2ab5b
# 49                     NaN    M5G 1C3    ON  4ae9ef82f964a520cbb721e3

# %% [markdown]
# From this dataframe, we can see that the two Cuban/Caribbean restaurants are located in postalcode M6H and M8V. For postalcode M6H, this means that the restaurant is located near Dufferin, therefore we can remove it from our list of neighborhood options.

# %% [markdown]
# ### Using K-Means Clustering and a Folium Map

# %%
# Create dataset with 7 remaining neighborhoods
import pandas as pd
neigh = [('M4V', 'Summerhill West', '43.686412','-79.400049'), ('M5A','Regent Park','43.654260','-79.360636'),('M5J','Harbourfront East','43.640816','-79.381752'),
         ('M5V','CN Tower','43.628947','-79.394420'),('M6G','Christie','43.669542','-79.422564'),('M6J','Little Portugal','43.647927','-79.419750'),
         ('M6S','Runnymede','43.651571','-79.484450')]
df = pd.DataFrame(neigh, columns = ['PostalCode', 'Neighborhood', 'Latitude', 'Longitude'])
df
# Out:
#   PostalCode       Neighborhood   Latitude   Longitude
# 0        M4V    Summerhill West  43.686412  -79.400049
# 1        M5A        Regent Park  43.654260  -79.360636
# 2        M5J  Harbourfront East  43.640816  -79.381752
# 3        M5V           CN Tower  43.628947  -79.394420
# 4        M6G           Christie  43.669542  -79.422564
# 5        M6J    Little Portugal  43.647927  -79.419750
# 6        M6S          Runnymede  43.651571  -79.484450

# %%
map_toronto = folium.Map(location=[latitude, longitude],zoom_start=15)
for lat,lng,postal,neighborhood in zip(df['Latitude'],df['Longitude'],df['PostalCode'],df['Neighborhood']):
    label = '{}, {}'.format(neighborhood, postal)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
    [lat,lng],
    radius=5,
    popup=label,
    color='blue',
    fill=True,
    fill_color='#3186cc',
    fill_opacity=0.7,
    parse_html=False).add_to(map_toronto)
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# From this map, we can see where the selected neighborhoods are in Toronto.  Notice that there are four neighborhoods that are very close to one another.  If we narrow our choices to these four and select the one with highest number of Latin Americans present, we will select CN Tower, postalcode M5V, as our area for where the Cuban restaurant should be opened.
